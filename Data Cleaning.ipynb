# %% [markdown]
# <a href="https://colab.research.google.com/github/shingi2020/shingi2020/blob/main/Data%20Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import numpy as np
import sklearn

# %%
june = pd.read_csv('/content/CEBS_June.csv')

# %%
june.head(5)
# Out:
#   Date of Alert            Province    District     Ward  Location Name  \
# 0      6/5/2024  Matabeleland South  Beitbridge   Ward 2          Dite
# 1      6/5/2024  Matabeleland South  Beitbridge   Ward 2          Dite
# 2      6/5/2024  Matabeleland South  Beitbridge   Ward 2          Dite
# 3      6/5/2024  Matabeleland South  Beitbridge   Ward 2          Dite
# 4     6/20/2024              Harare      Harare  Ward 24  Old Highfield
#
#      A2.05. Location GIS coordinates   Latitude  Longitude  altitude  \
# 0                                NaN -22.223355  30.388859       NaN
# 1                                NaN -22.223355  30.388859       NaN
# 2                                NaN -22.223355  30.388859       NaN
# 3                                NaN -22.223355  30.388859       NaN
# 4  -17.8828232 30.9939889 1436.0 4.0 -17.882823  30.993989    1436.0
#
#    Location GIS coordinates_precision  \
# 0                                 NaN
# 1                                 NaN
# ...

# %%
hre_data = june[june ['District']=='Harare']

# %%
# Write the filtered data to a CSV file named 'harare_data.csv'
hre_data.to_csv('harare_data.csv', index=False)

# %%
byo_data = june[june ['District']=='Bulawayo']

# %%
byo_data.to_csv('byo_data.csv', index=False)

# %%
mas_data = june[june['District']=='Masvingo']

# %%
mas_data.to_csv('mas_data.csv', index=False)

# %%
bb_data = june[(june['District']=='Beitbridge')|(june['District']== 'Beitbridge Urban')]

# %%
bb_data.to_csv('bb_data.csv', index=False)

# %%
#Remove the N/a fields in the Event Type column
hre_filtered = hre_data[hre_data['Event Type'] != 'N/a']

# %%
print(hre_filtered)
# Out:
#     Date of Alert Province District     Ward      Location Name  \
# 4       6/20/2024   Harare   Harare  Ward 24      Old Highfield
# 5       6/20/2024   Harare   Harare  Ward 24      Old Highfield
# 6       6/20/2024   Harare   Harare  Ward 24      Old Highfield
# 7       6/20/2024   Harare   Harare  Ward 24      Old Highfield
# 8        6/6/2024   Harare   Harare   Ward 9  Mbare High school
# ..            ...      ...      ...      ...                ...
# 862     6/10/2024   Harare   Harare   Ward 3     Mbare national
# 864     6/10/2024   Harare   Harare   Ward 3     Mbare national
# 865     6/10/2024   Harare   Harare   Ward 3     Mbare national
# 866     6/10/2024   Harare   Harare   Ward 3     Mbare national
# 867      6/6/2024   Harare   Harare  Ward 27        Glennorah B
#
#                      A2.05. Location GIS coordinates   Latitude  Longitude  \
# 4                  -17.8828232 30.9939889 1436.0 4.0 -17.882823  30.993989
# ...
